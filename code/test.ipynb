# %% [markdown]
# Test!

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib
from matplotlib.animation import FuncAnimation
import numpy as np
import PIL
from IPython.display import display, clear_output, HTML
rc('animation', html='html5')

def update(img):
    ax.clear()
    res = ax.imshow(img, cmap="gray")
    return res 

# Save images to array
images = []
for i in range(1, 65):
    num = str(i) if i >= 10 else "0" + str(i)
    image = PIL.Image.open(f"./toyProblem_F22/frame_{num}.png").convert("L")
    image = np.asarray(image)
    # image = np.reshape(image, (-1,))
    # images.append(np.asarray(image, dtype=np.float32)/255)
    images.append(image)

# Plot images in sequence
fig, ax = plt.subplots()
# for i, img in enumerate(images):
#     ax.clear()
#     ax.imshow(img, cmap="gray")
#     ax.set_title(f"frame {i}")
#     # Note that using time.sleep does *not* work here!
#     plt.pause(0.05)


ani = matplotlib.animation.ArtistAnimation(fig, images, 
                                        interval=50, blit=True, repeat_delay = 1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb Cell 3 in <cell line: 35>()
#      <a href='vscode-notebook-cell:/Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> fig, ax = plt.subplots()
#      <a href='vscode-notebook-cell:/Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a> # for i, img in enumerate(images):
#      <a href='vscode-notebook-cell:/Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> #     ax.clear()
# ...

# %%
220202
# Out:
# 220202

# %%
# !brew install ffmpeg
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 4 taps (homebrew/cask-versions, homebrew/core, homebrew/cask and gcenx/wine).
# ==> New Formulae
# cargo-make                 crfsuite                   qdmr
# cargo-release              libaribcaption             tetra
# clang-build-analyzer       opencl-clhpp-headers       xcdiff
# ==> New Casks
# capslocknodelay            monofocus                  spotify4bigsur
# copilot-for-xcode          pokemon-tcg-live           spybuster
# lotus                      rive                       ulbow
#
# You have 27 outdated formulae and 3 outdated casks installed.
# You can upgrade them with brew upgrade
# or list them with brew outdated.
#
# ...

# %%
plt.imshow(images[1], cmap="gray")
plt.show()

# %%
# importing matplot lib
import matplotlib.pyplot as plt
import numpy as np
 
# importing movie py libraries
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage
 
# numpy array
x = np.linspace(-2, 2, 200)

# duration of the video
duration = 5
 
# matplot subplot
fig, ax = plt.subplots()
 
# method to get frames
def make_frame(time):
     
    idx += 1

    # clear
    ax.clear()
     
    # plotting line
    ax.imshow(images[int(time)], cmap="gray")
     
    # returning numpy image
    return images[int(time)]

# creating animation
animation = VideoClip(make_frame, duration = duration)

animation.write_gif("test.gif",fps=1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb Cell 7 in <cell line: 34>()
#      <a href='vscode-notebook-cell:/Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a>     return images[idx]
#      <a href='vscode-notebook-cell:/Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb#X12sZmlsZQ%3D%3D?line=32'>33</a> # creating animation
# ---> <a href='vscode-notebook-cell:/Users/mikael/Documents/DTU/mathematical_modeling_02526/02526-mathematical-modeling-project-1/code/test.ipynb#X12sZmlsZQ%3D%3D?line=33'>34</a> animation = VideoClip(make_frame, duration = duration)
# ...
